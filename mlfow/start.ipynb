# %% [markdown]
# # MLFlow Tracking Server

# %%
import mlflow

# %% [markdown]
# before we need to run mlflow server running with this command:
# mlflow uri

# %%
mlflow.set_tracking_uri(uri="http://127.0.0.1:5000")
# this means every experiment we are running is running in this url.

# %%
mlflow.set_experiment("Check localhost connection")

with mlflow.start_run():
    mlflow.log_metric("test1",1)
    mlflow.log_metric("test2",2)
# Out:
# 2026/08/27 01:30:54 INFO mlflow.tracking.fluent: Experiment with name 'Check localhost connection' does not exist. Creating a new experiment.
# 🏃 View run thundering-mule-612 at: http://127.0.0.1:5000/#/experiments/1/runs/fea02e5f64fb4a64aa333de040343396
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/1

# %%
with mlflow.start_run():
    mlflow.log_metric("test3",1)
    mlflow.log_metric("test4",2)
# Out:
# 🏃 View run bittersweet-lamb-238 at: http://127.0.0.1:5000/#/experiments/1/runs/6e3c0eaf69754cc39f289cc4f266f3dd
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/1
