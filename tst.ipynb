# %% [markdown]
# # Practice Notebook

# %% [markdown]
# ## Python recap

# %% [markdown]
# ### Topics
# - exception handling
# - OOP
# - data
# - logging

# %% [markdown]
# ## Flask

# %% [markdown]
# ## MLflow
